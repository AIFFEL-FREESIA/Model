# %% [markdown]
# # E24_E2_retrain
# ---

# %% [markdown]
# ## Environment Setting
# ---

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import math
import numpy as np
import tensorflow as tf
import keras
import h5py
from pathlib import Path

import matplotlib.pyplot as plt
import cv2
import math
from tqdm import tqdm

# %env SM_FRAMEWORK=tf.keras
import segmentation_models as sm
import albumentations as A

import seaborn
seaborn.set(style='white')
seaborn.set_context('paper')
# Out:
# env: SM_FRAMEWORK=tf.keras
# Segmentation Models: using `tf.keras` framework.

# %%
import tensorflow as tf
def init_gpu():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')

            print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs\n\n")
        except RuntimeError as e:
            # Memory growth must be set before GPUs have been initialized
            print(e, "\n\n")

init_gpu()
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# !pwd
# Out:
# /home/aiffel-dj1/workspace/Hackerton/workspace/Model

# %%
FILE_PATH = '/home/aiffel-dj1/workspace/Hackerton/workspace/Model/data/LV1_PNG_DATASET_R.h5'
BASE_TARIN_DIR = "/train"
TRAIN_IMG_PATH = f'{Path(BASE_TARIN_DIR)}/img'
TRAIN_LABEL_PATH = f'{Path(BASE_TARIN_DIR)}/label'                                                                                                               

BASE_VAL_DIR = "/val"
VAL_IMG_PATH = f'{Path(BASE_VAL_DIR)}/img'
VAL_LABEL_PATH = f'{Path(BASE_VAL_DIR)}/label'
 

BASE_TEST_DIR = "/test"
TEST_IMG_PATH = f'{Path(BASE_TEST_DIR)}/img'
TEST_LABEL_PATH = f'{Path(BASE_TEST_DIR)}/label'


IMAGE_SIZE = 1024
IMG_CHANNELS = 3

COLOR_MAP = [
    (165, 42, 42),
    (0, 192, 0),
    (255,255,255)
]

# %% [markdown]
# ### dataset 확인

# %%
import matplotlib.pyplot as plt
i = 0

with h5py.File(FILE_PATH, 'r') as hdf5_file:
    plt.suptitle('TRAIN DATA')
    plt.subplot(121)
    plt.imshow(hdf5_file[TRAIN_IMG_PATH][i])
    plt.subplot(122)
    plt.imshow(hdf5_file[TRAIN_LABEL_PATH][i])
    plt.show()
    
    plt.suptitle('VAL DATA')
    plt.subplot(121)
    plt.imshow(hdf5_file[VAL_IMG_PATH][i])
    plt.subplot(122)
    plt.imshow(hdf5_file[VAL_LABEL_PATH][i])
    plt.show()
    
    plt.suptitle('TEST DATA')
    plt.subplot(121)
    plt.imshow(hdf5_file[TEST_IMG_PATH][i])
    plt.subplot(122)
    plt.imshow(hdf5_file[TEST_LABEL_PATH][i])
    plt.show()

# %% [markdown]
# ## Dataloader and utility functions
# ---

# %%
def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    fig, axs = plt.subplots(1, n, figsize=(10, 5))
    
    for i, (name, image) in enumerate(images.items()):
        axs[i].set_xticks([])
        axs[i].set_yticks([])
        axs[i].set_title(' '.join(name.split('_')).title())
        axs[i].imshow(image)
        
    plt.tight_layout()
    plt.show()

# %%
# helper function for data visualization    
def denormalize(x):
    """Scale image to range 0..1 for correct plot"""
    x_max = np.percentile(x, 98)
    x_min = np.percentile(x, 2)    
    x = (x - x_min) / (x_max - x_min)
    x = x.clip(0, 1)
    return x

# %%
def round_clip_0_1(x, **kwargs):
    return x.round().clip(0, 1)

def get_training_augmentation():
    train_transform = [
        A.RandomRotate90(p=0.5),
        A.RandomRotate90(p=0.5),
        A.RandomRotate90(p=0.5),
        A.Resize(width=256, height=256),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(train_transform)


def get_validation_augmentation():
    """Add paddings to make image shape divisible by 32"""
    test_transform = [
        A.Resize(width=256, height=256),
        A.Lambda(mask=round_clip_0_1)
    ]
    return A.Compose(test_transform)

def get_preprocessing(preprocessing_fn):
    """Construct preprocessing transform
    
    Args:
        preprocessing_fn (callbale): data normalization function 
            (can be specific for each pretrained neural network)
    Return:
        transform: albumentations.Compose
    
    """
    _transform = [
        A.CLAHE(clip_limit=2.0, tile_grid_size=(32, 32), p=1),
        A.Lambda(image=preprocessing_fn),
    ]
    return A.Compose(_transform)

# %%
class SatelliteGenerator(tf.keras.utils.Sequence):
    '''
    ref: https://github.com/AIFFEL-FREESIA/Model/blob/master/Unet_building_256_2.ipynb
    SatelliteGenerator는 tf.keras.utils.Sequence를 상속받습니다.
    '''
    def __init__(self, 
                 filepath,
                 x_path,
                 y_path,
                 batch_size=8,
                 augmentation=None, 
                 preprocessing=None,
                 is_train=True):
        
        self.filepath = filepath
        self.x_path = x_path
        self.y_path = y_path
        
        self.augmentation = augmentation
        self.preprocessing = preprocessing

        self.size = 0
        with h5py.File(self.filepath, 'r') as f:
            self.size = f[x_path].shape[0]
            
        self.batch_size = batch_size
        self.is_train = is_train
    
    def __len__(self):
        return math.ceil(self.size / self.batch_size)

    def __getitem__(self, index):
        with h5py.File(self.filepath, 'r') as f:
            images = f[self.x_path][index*self.batch_size : (index + 1)*self.batch_size]
            masks = f[self.y_path][index*self.batch_size : (index + 1)*self.batch_size]
            
            masks = [(mask == COLOR_MAP[1]) for mask in masks]
            masks = [(mask[:,:,0] +  mask[:,:,1] +  mask[:,:,2]).astype(np.float32) for mask in masks]
            
            res = [(img, mask) for img, mask in zip(images, masks)]

            if self.augmentation:
                res = [self.augmentation(image=img, mask=mask) for img, mask in res]
                res = [(r['image'], r['mask']) for r in res]
            if self.preprocessing:
                res = [self.preprocessing(image=img, mask=mask) for img, mask in res]
                res = [(r['image'], r['mask']) for r in res]
            
            images = np.array([img for img, _ in res ])
            masks = np.array([mask for _, mask in res ])
            
            return images, masks

    def on_epoch_end(self):
        # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
        self.indexes = np.arange(self.size)
        if self.is_train == True :
            np.random.shuffle(self.indexes)
        
        return self.indexes

# %%
# Lets look at augmented data we have
dataset = SatelliteGenerator(
    FILE_PATH,
    TRAIN_IMG_PATH,
    TRAIN_LABEL_PATH, 
    augmentation=get_training_augmentation()
)

dataset_aug = SatelliteGenerator(
    FILE_PATH,
    TRAIN_IMG_PATH,
    TRAIN_LABEL_PATH, 
    augmentation=get_training_augmentation())

preprocess_input = sm.get_preprocessing('efficientnetb3')
dataset_aug_pre = SatelliteGenerator(
    FILE_PATH,
    TRAIN_IMG_PATH,
    TRAIN_LABEL_PATH,
    augmentation=get_training_augmentation(),
    preprocessing=get_preprocessing(preprocess_input)
)

idx = 10
image, mask = dataset[idx] # get some sample
image_aug, mask_aug = dataset_aug[idx]
image_aug_pre, mask_aug_pre = dataset_aug_pre[idx]


visualize(
    image=image[0], 
    augmentation=image_aug[0],
    augmentation_and_preprocessing=denormalize(image_aug_pre[0])
)

visualize(
    building_mask=mask[0],
    augmentation=mask_aug[0],
    augmentation_and_preprocessing=mask_aug_pre[0]
)

# %% [markdown]
# # Train Model

# %% [markdown]
# ### functions

# %%
def get_datagenerator(BATCH_SIZE=8, BACKBONE='efficientnetb3'):
    # Dataset for train images
    preprocess_input = sm.get_preprocessing(BACKBONE)
    train_datagenerator = SatelliteGenerator(
        FILE_PATH,
        TRAIN_IMG_PATH,
        TRAIN_LABEL_PATH,
        batch_size=BATCH_SIZE,
        augmentation=get_training_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
        is_train=True
    )

    # Dataset for validation image
    valid_datagenerator = SatelliteGenerator(
        FILE_PATH,
        VAL_IMG_PATH, 
        VAL_LABEL_PATH, 
        batch_size=BATCH_SIZE,
        augmentation=get_validation_augmentation(),
        preprocessing=get_preprocessing(preprocess_input),
        is_train=False
    )

    return train_datagenerator, valid_datagenerator

# %%
import time
import datetime
def logging_time(original_fn):
    def wrapper_fn(*args, **kwargs):
        start_time = time.time()
        
        result = original_fn(*args, **kwargs)
        
        sec = time.time()-start_time
        times = str(datetime.timedelta(seconds=sec)).split(".")
        times = times[0]
        print(f'WorkingTime : {times}')
        return result
    return wrapper_fn

# %%
def get_cosine_lr(initial_learning_rate, t_period, lr_min=0.):
    return tf.keras.experimental.CosineDecay(
        initial_learning_rate=initial_learning_rate,
        decay_steps=t_period, alpha=lr_min / initial_learning_rate)

# %%
def get_model(optim, train, valid, MODEL_PATH, patience=5):
    BACKBONE = 'efficientnetb3'
    CLASSES = ['building']

    # define network parameters
    n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)  # case for binary and multiclass segmentation
    activation = 'sigmoid' if n_classes == 1 else 'softmax'

    #create model
    model = sm.Unet(BACKBONE, classes=n_classes, activation=activation, encoder_weights='imagenet')

    # Segmentation models losses can be combined together by '+' and scaled by integer or float factor
    dice_loss = sm.losses.DiceLoss()
    focal_loss = sm.losses.BinaryFocalLoss() if n_classes == 1 else sm.losses.CategoricalFocalLoss()
    total_loss = dice_loss + (1 * focal_loss)
    metrics = [sm.metrics.IOUScore(threshold=0.5), sm.metrics.FScore(threshold=0.5)]

    # compile keras model with defined optimozer, loss and metrics
    model.compile(optim, total_loss, metrics)
    
    log_dir = "../logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
    callbacks = [
        keras.callbacks.ModelCheckpoint(MODEL_PATH, save_weights_only=True, save_best_only=True, mode='min', monitor='val_loss'),
        keras.callbacks.ReduceLROnPlateau(),
        tensorboard_callback,
        keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=patience)
    ]
    
    return model, callbacks

# %%
def show_history_plot(history):
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    keys = [('loss', 'val_loss'), ('iou_score', 'val_iou_score'), ('f1-score', 'val_f1-score')]
    
    for (train, val), ax in zip(keys, axes):
        ax.plot(history[train])
        ax.plot(history[val])
        ax.set_title(f'Model {train}')
        ax.set_ylabel(train)
        ax.set_xlabel('Epoch')
        ax.legend(['Train', 'Validation'], loc='upper left')

    plt.tight_layout()
    plt.show()
# show_history_plot(new_history)

# %%
def inference(model, img):
    preprocessing = A.Compose([
        A.Resize(width=256, height=256),
        A.CLAHE(clip_limit=2.0, tile_grid_size=(32, 32), p=1),
        A.Lambda(image=sm.get_preprocessing(BACKBONE)),
    ])

    img_preprocessed = preprocessing(image=img)['image']
    img_preprocessed = np.expand_dims(img_preprocessed, axis=0)
    predicted = model.predict(img_preprocessed)
    predicted = predicted[..., 0].squeeze()
    predicted = predicted.round().clip(0, 1)
    
    return predicted

# %%
def show_inference(model):
    with h5py.File(FILE_PATH, "r") as f:
        for idx in range(5):
            img = f[TEST_IMG_PATH][idx]
            mask = (f[TEST_LABEL_PATH][idx] == COLOR_MAP[1])
            mask = (mask[:,:,0] +  mask[:,:,1] +  mask[:,:,2]).astype(np.float32)


            predicted = inference(model, img)
            images = {'Image': img, 
                      'Ground Truth': mask,
                      'Prediction': predicted}

            visualize(
                image=img,
                ground_truth=mask,
                predicted=predicted
            )

# %% [markdown]
# ### Train
# - CLAHE, gride size = 32, 32
# - optimizer = Adam
#     - initial_learning_rate = 1e-4
# - EPOCHS=100
# - Batch=8

# %%
lr = 1e-4
BATCH_SIZE = 8
EPOCHS=100
optim = keras.optimizers.Adam(learning_rate=lr)
train_datagenerator, valid_datagenerator = get_datagenerator(BATCH_SIZE=BATCH_SIZE)

# %%
model, callbacks = get_model(optim,
                             train_datagenerator, 
                             valid_datagenerator,
                             '/home/aiffel-dj1/workspace/Hackerton/workspace/Model/trained_model/E24_best_model.h5',
                             patience=10)

# %%
start_time = time.time()

history = model.fit(
    train_datagenerator, 
    steps_per_epoch=len(train_datagenerator), 
    epochs=EPOCHS, 
    callbacks=callbacks, 
    validation_data=valid_datagenerator, 
    validation_steps=len(valid_datagenerator))

sec = time.time()-start_time
times = str(datetime.timedelta(seconds=sec)).split(".")
times = times[0]
print(f'WorkingTime : {times}')
# Out:
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function f_score at 0x7fc36e667830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function f_score at 0x7fc36e667830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function binary_focal_loss at 0x7fc36e667b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function binary_focal_loss at 0x7fc36e667b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function iou_score at 0x7fc36e6677a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function iou_score at 0x7fc36e6677a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 128/128 [==============================] - 157s 273ms/step - loss: 0.8887 - iou_score: 0.1684 - f1-score: 0.2770 - val_loss: 0.7406 - val_iou_score: 0.3535 - val_f1-score: 0.5189
# Epoch 2/100
# 128/128 [==============================] - 31s 237ms/step - loss: 0.7251 - iou_score: 0.3635 - f1-score: 0.5243 - val_loss: 0.6677 - val_iou_score: 0.4053 - val_f1-score: 0.5727
# Epoch 3/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.6455 - iou_score: 0.3965 - f1-score: 0.5596 - val_loss: 0.6183 - val_iou_score: 0.4312 - val_f1-score: 0.5994
# Epoch 4/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.5943 - iou_score: 0.4163 - f1-score: 0.5826 - val_loss: 0.5654 - val_iou_score: 0.4374 - val_f1-score: 0.6049
# Epoch 5/100
# 128/128 [==============================] - 30s 235ms/step - loss: 0.5468 - iou_score: 0.4410 - f1-score: 0.6077 - val_loss: 0.5193 - val_iou_score: 0.4465 - val_f1-score: 0.6124
# Epoch 6/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.5198 - iou_score: 0.4531 - f1-score: 0.6184 - val_loss: 0.4946 - val_iou_score: 0.4642 - val_f1-score: 0.6300
# Epoch 7/100
# 128/128 [==============================] - 30s 235ms/step - loss: 0.4943 - iou_score: 0.4706 - f1-score: 0.6363 - val_loss: 0.4875 - val_iou_score: 0.4671 - val_f1-score: 0.6331
# Epoch 8/100
# 128/128 [==============================] - 30s 235ms/step - loss: 0.4644 - iou_score: 0.4965 - f1-score: 0.6597 - val_loss: 0.4740 - val_iou_score: 0.4697 - val_f1-score: 0.6345
# Epoch 9/100
# 128/128 [==============================] - 30s 235ms/step - loss: 0.4452 - iou_score: 0.5081 - f1-score: 0.6706 - val_loss: 0.4733 - val_iou_score: 0.4691 - val_f1-score: 0.6338
# Epoch 10/100
# 128/128 [==============================] - 31s 237ms/step - loss: 0.4129 - iou_score: 0.5399 - f1-score: 0.6973 - val_loss: 0.4683 - val_iou_score: 0.4736 - val_f1-score: 0.6392
# Epoch 11/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.4220 - iou_score: 0.5258 - f1-score: 0.6850 - val_loss: 0.4607 - val_iou_score: 0.4769 - val_f1-score: 0.6420
# Epoch 12/100
# 128/128 [==============================] - 30s 235ms/step - loss: 0.4068 - iou_score: 0.5440 - f1-score: 0.7018 - val_loss: 0.4628 - val_iou_score: 0.4767 - val_f1-score: 0.6412
# Epoch 13/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.4061 - iou_score: 0.5402 - f1-score: 0.6976 - val_loss: 0.4533 - val_iou_score: 0.4859 - val_f1-score: 0.6502
# Epoch 14/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.3943 - iou_score: 0.5523 - f1-score: 0.7089 - val_loss: 0.4562 - val_iou_score: 0.4845 - val_f1-score: 0.6493
# Epoch 15/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.3893 - iou_score: 0.5545 - f1-score: 0.7108 - val_loss: 0.4517 - val_iou_score: 0.4879 - val_f1-score: 0.6523
# Epoch 16/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.3779 - iou_score: 0.5650 - f1-score: 0.7183 - val_loss: 0.4546 - val_iou_score: 0.4772 - val_f1-score: 0.6420
# Epoch 17/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.3757 - iou_score: 0.5655 - f1-score: 0.7197 - val_loss: 0.4437 - val_iou_score: 0.4948 - val_f1-score: 0.6582
# Epoch 18/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.3703 - iou_score: 0.5740 - f1-score: 0.7264 - val_loss: 0.4409 - val_iou_score: 0.4981 - val_f1-score: 0.6614
# Epoch 19/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.3627 - iou_score: 0.5761 - f1-score: 0.7285 - val_loss: 0.4450 - val_iou_score: 0.4943 - val_f1-score: 0.6581
# Epoch 20/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.3610 - iou_score: 0.5802 - f1-score: 0.7305 - val_loss: 0.4450 - val_iou_score: 0.4961 - val_f1-score: 0.6599
# Epoch 21/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.3563 - iou_score: 0.5862 - f1-score: 0.7352 - val_loss: 0.4447 - val_iou_score: 0.4909 - val_f1-score: 0.6546
# Epoch 22/100
# 128/128 [==============================] - 30s 236ms/step - loss: 0.3485 - iou_score: 0.5920 - f1-score: 0.7408 - val_loss: 0.4483 - val_iou_score: 0.4866 - val_f1-score: 0.6509
# Epoch 23/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.3402 - iou_score: 0.6015 - f1-score: 0.7462 - val_loss: 0.4410 - val_iou_score: 0.4990 - val_f1-score: 0.6622
# Epoch 24/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.3555 - iou_score: 0.5888 - f1-score: 0.7372 - val_loss: 0.4400 - val_iou_score: 0.4996 - val_f1-score: 0.6628
# Epoch 25/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.3389 - iou_score: 0.6038 - f1-score: 0.7494 - val_loss: 0.4456 - val_iou_score: 0.4944 - val_f1-score: 0.6580
# Epoch 26/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.3278 - iou_score: 0.6111 - f1-score: 0.7562 - val_loss: 0.4424 - val_iou_score: 0.4922 - val_f1-score: 0.6557
# Epoch 27/100
# 128/128 [==============================] - 30s 231ms/step - loss: 0.3262 - iou_score: 0.6156 - f1-score: 0.7593 - val_loss: 0.4414 - val_iou_score: 0.4947 - val_f1-score: 0.6579
# Epoch 28/100
# 128/128 [==============================] - 30s 231ms/step - loss: 0.3264 - iou_score: 0.6134 - f1-score: 0.7568 - val_loss: 0.4424 - val_iou_score: 0.5041 - val_f1-score: 0.6669
# Epoch 29/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.3154 - iou_score: 0.6247 - f1-score: 0.7665 - val_loss: 0.4350 - val_iou_score: 0.4994 - val_f1-score: 0.6627
# Epoch 30/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.3181 - iou_score: 0.6196 - f1-score: 0.7632 - val_loss: 0.4370 - val_iou_score: 0.4998 - val_f1-score: 0.6630
# Epoch 31/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.3030 - iou_score: 0.6335 - f1-score: 0.7734 - val_loss: 0.4425 - val_iou_score: 0.5037 - val_f1-score: 0.6669
# Epoch 32/100
# 128/128 [==============================] - 30s 230ms/step - loss: 0.3006 - iou_score: 0.6367 - f1-score: 0.7763 - val_loss: 0.4435 - val_iou_score: 0.4991 - val_f1-score: 0.6628
# Epoch 33/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.3039 - iou_score: 0.6355 - f1-score: 0.7747 - val_loss: 0.4415 - val_iou_score: 0.4985 - val_f1-score: 0.6618
# Epoch 34/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.3019 - iou_score: 0.6382 - f1-score: 0.7762 - val_loss: 0.4383 - val_iou_score: 0.5012 - val_f1-score: 0.6644
# Epoch 35/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.2940 - iou_score: 0.6437 - f1-score: 0.7807 - val_loss: 0.4412 - val_iou_score: 0.5007 - val_f1-score: 0.6638
# Epoch 36/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.3063 - iou_score: 0.6324 - f1-score: 0.7719 - val_loss: 0.4398 - val_iou_score: 0.4981 - val_f1-score: 0.6611
# Epoch 37/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.2875 - iou_score: 0.6508 - f1-score: 0.7862 - val_loss: 0.4365 - val_iou_score: 0.5046 - val_f1-score: 0.6672
# Epoch 38/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.2957 - iou_score: 0.6444 - f1-score: 0.7810 - val_loss: 0.4329 - val_iou_score: 0.5037 - val_f1-score: 0.6663
# Epoch 39/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.3003 - iou_score: 0.6429 - f1-score: 0.7799 - val_loss: 0.4410 - val_iou_score: 0.4938 - val_f1-score: 0.6571
# Epoch 40/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.3076 - iou_score: 0.6342 - f1-score: 0.7719 - val_loss: 0.4329 - val_iou_score: 0.5069 - val_f1-score: 0.6693
# Epoch 41/100
# 128/128 [==============================] - 30s 234ms/step - loss: 0.2933 - iou_score: 0.6461 - f1-score: 0.7824 - val_loss: 0.4388 - val_iou_score: 0.4966 - val_f1-score: 0.6601
# Epoch 42/100
# 128/128 [==============================] - 30s 233ms/step - loss: 0.2705 - iou_score: 0.6671 - f1-score: 0.7987 - val_loss: 0.4364 - val_iou_score: 0.4985 - val_f1-score: 0.6620
# Epoch 43/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.2788 - iou_score: 0.6595 - f1-score: 0.7929 - val_loss: 0.4394 - val_iou_score: 0.5012 - val_f1-score: 0.6644
# Epoch 44/100
# 128/128 [==============================] - 30s 231ms/step - loss: 0.2726 - iou_score: 0.6688 - f1-score: 0.7991 - val_loss: 0.4418 - val_iou_score: 0.4959 - val_f1-score: 0.6596
# Epoch 45/100
# 128/128 [==============================] - 30s 232ms/step - loss: 0.2817 - iou_score: 0.6592 - f1-score: 0.7919 - val_loss: 0.4417 - val_iou_score: 0.4957 - val_f1-score: 0.6592
# Epoch 46/100
# 128/128 [==============================] - 31s 239ms/step - loss: 0.2697 - iou_score: 0.6699 - f1-score: 0.7997 - val_loss: 0.4381 - val_iou_score: 0.5007 - val_f1-score: 0.6636
# Epoch 47/100
# 128/128 [==============================] - 30s 236ms/step - loss: 0.2762 - iou_score: 0.6668 - f1-score: 0.7972 - val_loss: 0.4372 - val_iou_score: 0.5059 - val_f1-score: 0.6686
# Epoch 48/100
# 128/128 [==============================] - 29s 229ms/step - loss: 0.2713 - iou_score: 0.6682 - f1-score: 0.7990 - val_loss: 0.4403 - val_iou_score: 0.4953 - val_f1-score: 0.6592
# Epoch 49/100
# 128/128 [==============================] - 30s 230ms/step - loss: 0.2576 - iou_score: 0.6824 - f1-score: 0.8089 - val_loss: 0.4344 - val_iou_score: 0.5023 - val_f1-score: 0.6651
# Epoch 50/100
# 128/128 [==============================] - 31s 238ms/step - loss: 0.2663 - iou_score: 0.6756 - f1-score: 0.8042 - val_loss: 0.4328 - val_iou_score: 0.5057 - val_f1-score: 0.6682
# Epoch 51/100
# 128/128 [==============================] - 33s 253ms/step - loss: 0.2626 - iou_score: 0.6794 - f1-score: 0.8066 - val_loss: 0.4334 - val_iou_score: 0.5055 - val_f1-score: 0.6681
# Epoch 52/100
# 128/128 [==============================] - 32s 252ms/step - loss: 0.2595 - iou_score: 0.6845 - f1-score: 0.8104 - val_loss: 0.4329 - val_iou_score: 0.5058 - val_f1-score: 0.6684
# Epoch 53/100
# 128/128 [==============================] - 32s 249ms/step - loss: 0.2611 - iou_score: 0.6845 - f1-score: 0.8098 - val_loss: 0.4336 - val_iou_score: 0.5068 - val_f1-score: 0.6693
# Epoch 54/100
# 128/128 [==============================] - 32s 252ms/step - loss: 0.2684 - iou_score: 0.6769 - f1-score: 0.8047 - val_loss: 0.4347 - val_iou_score: 0.5060 - val_f1-score: 0.6687
# Epoch 55/100
# 128/128 [==============================] - 33s 260ms/step - loss: 0.2572 - iou_score: 0.6864 - f1-score: 0.8117 - val_loss: 0.4336 - val_iou_score: 0.5056 - val_f1-score: 0.6682
# Epoch 56/100
# 128/128 [==============================] - 32s 247ms/step - loss: 0.2508 - iou_score: 0.6924 - f1-score: 0.8157 - val_loss: 0.4336 - val_iou_score: 0.5065 - val_f1-score: 0.6690
# Epoch 57/100
# 128/128 [==============================] - 33s 253ms/step - loss: 0.2546 - iou_score: 0.6880 - f1-score: 0.8127 - val_loss: 0.4344 - val_iou_score: 0.5071 - val_f1-score: 0.6696
# Epoch 58/100
# 128/128 [==============================] - 33s 255ms/step - loss: 0.2682 - iou_score: 0.6756 - f1-score: 0.8024 - val_loss: 0.4344 - val_iou_score: 0.5057 - val_f1-score: 0.6683
# Epoch 59/100
# 128/128 [==============================] - 32s 248ms/step - loss: 0.2574 - iou_score: 0.6866 - f1-score: 0.8115 - val_loss: 0.4338 - val_iou_score: 0.5053 - val_f1-score: 0.6679
# Epoch 60/100
# 128/128 [==============================] - 33s 254ms/step - loss: 0.2613 - iou_score: 0.6841 - f1-score: 0.8087 - val_loss: 0.4351 - val_iou_score: 0.5045 - val_f1-score: 0.6672
# Epoch 00060: early stopping
# WorkingTime : 0:33:55

# %%
show_history_plot(history.history)

# %% [markdown]
# #### evaluation

# %%
model.load_weights('/home/aiffel-dj1/workspace/Hackerton/workspace/Model/trained_model/E24_best_model.h5')

# %%
preprocess_input = sm.get_preprocessing('efficientnetb3')
test_datagenerator = SatelliteGenerator(
    FILE_PATH,
    TEST_IMG_PATH, 
    TEST_LABEL_PATH, 
    batch_size=BATCH_SIZE,
    augmentation=get_validation_augmentation(),
    preprocessing=get_preprocessing(preprocess_input),
    is_train=False
)
val_metrix = model.evaluate(valid_datagenerator)
test_metrix = model.evaluate(test_datagenerator)
# Out:
# 15/15 [==============================] - 2s 161ms/step - loss: 0.4328 - iou_score: 0.5057 - f1-score: 0.6682
# 16/16 [==============================] - 54s 4s/step - loss: 0.4428 - iou_score: 0.5022 - f1-score: 0.6657

# %%
BACKBONE = 'efficientnetb3'
show_inference(model)
